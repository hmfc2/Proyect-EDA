# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

import pandas as pd

# %%
#Como se ve los datos de ACT, que son los de actividades a nivel nacional, pero los datos sacados de SERNATUR, vienen en un 
# excel, de distintas hojas, se busco la hoja de las actividades a nivel comunal y los valores en UF, y se guardo de forma .csv 
# link de acceso: https://drive.google.com/file/d/1o1lp7bbChpzDCOPK0fUWyKxNnvd7_Hwz/view?usp=sharing

#

file_id_encuesta = "1o1lp7bbChpzDCOPK0fUWyKxNnvd7_Hwz"

url = f"https://drive.google.com/uc?id={file_id_encuesta}"

ventas_actividad = pd.read_csv(
    url,
    sep=";",
    engine="python"
)

ventas_actividad.head(20)
# Out:
#     Año Comercial Region del domicilio o casa matriz  \
# 0            2012                 Región de Tarapacá
# 1            2012                 Región de Tarapacá
# 2            2012                 Región de Tarapacá
# 3            2012                 Región de Tarapacá
# 4            2012                 Región de Tarapacá
# 5            2012                 Región de Tarapacá
# 6            2012                 Región de Tarapacá
# 7            2012                 Región de Tarapacá
# 8            2012                 Región de Tarapacá
# 9            2012                 Región de Tarapacá
# 10           2012                 Región de Tarapacá
# 11           2012                 Región de Tarapacá
# 12           2012                 Región de Tarapacá
# 13           2012                 Región de Tarapacá
# 14           2012                 Región de Tarapacá
# 15           2012                 Región de Tarapacá
# 16           2012                 Región de Tarapacá
# 17           2012                 Región de Tarapacá
# 18           2012                 Región de Tarapacá
# 19           2012                 Región de Tarapacá
#
#    Provincia del domicilio o casa matriz Comuna del domicilio o casa matriz  \
# 0                                Iquique                            Iquique
# 1                                Iquique                            Iquique
# 2                                Iquique                            Iquique
# 3                                Iquique                            Iquique
# 4                                Iquique                            Iquique
# 5                                Iquique                            Iquique
# 6                                Iquique                            Iquique
# 7                                Iquique                            Iquique
# 8                                Iquique                            Iquique
# 9                                Iquique                            Iquique
# 10                               Iquique                            Iquique
# 11                               Iquique                            Iquique
# 12                               Iquique                            Iquique
# 13                               Iquique                            Iquique
# 14                               Iquique                            Iquique
# 15                               Iquique                            Iquique
# 16                               Iquique                            Iquique
# 17                               Iquique                            Iquique
# 18                               Iquique                            Iquique
# 19                               Iquique                            Iquique
#
#     Actividad economica                          Glosa actividad economica  \
# 0                551001                             Actividades de hoteles
# 1                551002                             Actividades de moteles
# 2                559001  Actividades de residenciales para estudiantes ...
# 3                559009            Otras actividades de alojamiento n.c.p.
# 4                561000  Actividades de restaurantes y de servicio móvi...
# 5                562900  Suministro industrial de comidas por encargo; ...
# 6                563001  Actividades de discotecas y cabaret (night clu...
# 7                491100  Transporte interurbano de pasajeros por ferroc...
# 8                492210               Servicios de transporte de escolares
# 9                492220            Servicios de transporte de trabajadores
# 10               492230  Servicios de transporte de pasajeros en taxis ...
# 11               492240                 Servicios de transporte a turistas
# 12               492250      Transporte de pasajeros en buses interurbanos
# 13               492290  Otras actividades de transporte de pasajeros p...
# 14               502100  Transporte de pasajeros por vías de navegación...
# 15               511000              Transporte de pasajeros por vía aérea
# 16               771000       Alquiler de vehículos automotores sin chofer
# 17               791100                  Actividades de agencias de viajes
# 18               900001  Servicios de producción de obras de teatro, co...
# 19               900002  Actividades artísticas realizadas por bandas d...
#
#     Número de empresas Ventas anuales en UF  \
# 0                 85.0           516.282,96
# 1                  3.0                    *
# 2                 81.0            75.200,78
# 3                 22.0            59.725,64
# 4                406.0         1.084.098,49
# 5                236.0           289.941,43
# 6                  8.0                    *
# 7                  1.0                    *
# 8                 20.0             3.689,99
# 9                 54.0           515.299,22
# 10                65.0            21.179,67
# 11                12.0            15.090,34
# 12                47.0           160.276,30
# 13               269.0           418.287,64
# 14                 2.0                    *
# 15                 1.0                    *
# 16                40.0            73.827,23
# 17                23.0            33.504,22
# 18                 9.0                    *
# 19                 2.0                    *
#
#    Trabajadores dependientes informados ponderados Renta neta informada  \
# 0                                          515,166          68.130,9550
# 1                                            5,750                    *
# 2                                           84,417           5.989,1840
# 3                                           60,250           6.684,3820
# 4                                        1.080,583          89.823,7840
# 5                                          256,250          20.734,3960
# 6                                           11,583                    *
# 7                                            1,000                    *
# 8                                            0,000               0,0000
# 9                                          605,500          94.338,0870
# 10                                          12,417             879,3130
# 11                                          15,583           1.203,8570
# 12                                         315,917          32.075,8650
# 13                                         891,333          71.870,7690
# 14                                           7,417                    *
# 15                                           0,000                    *
# 16                                          15,250           5.108,4750
# 17                                          39,583           3.478,5460
# 18                                           4,083                    *
# 19                                           1,000                    *
#
#    Trabajadores a honorarios ponderados por meses trabajados  \
# 0                                                 166
# 1                                                   2
# 2                                                  48
# 3                                                  59
# 4                                                 231
# 5                                                 106
# 6                                                   4
# 7                                                   0
# 8                                                   0
# 9                                                  17
# 10                                                  6
# 11                                                  3
# 12                                                 12
# 13                                                 53
# 14                                                  1
# 15                                                  0
# 16                                                  7
# 17                                                  6
# 18                                                  3
# 19                                                  1
#
#    Honorarios pagados informados  COD_ACT  \
# 0                     16.350,792        1
# 1                              *        1
# 2                      3.211,949        1
# 3                      8.392,627        1
# 4                     14.714,293        2
# 5                      5.450,974        2
# 6                              *        2
# 7                              *        3
# 8                          0,687        4
# 9                      2.133,824        4
# 10                       879,552        4
# 11                       495,609        4
# 12                     1.022,900        4
# 13                     3.298,977        4
# 14                             *        5
# 15                             *        6
# 16                       186,793        7
# 17                     2.102,582        8
# 18                             *        9
# 19                             *        9
#
#                                                   ACT  CUT_comuna  \
# 0                               Alojamiento turístico        1101
# 1                               Alojamiento turístico        1101
# 2                               Alojamiento turístico        1101
# 3                               Alojamiento turístico        1101
# 4     Actividades de provisión de alimentos y bebidas        1101
# 5     Actividades de provisión de alimentos y bebidas        1101
# 6     Actividades de provisión de alimentos y bebidas        1101
# 7             Transporte de pasajeros por ferrocarril        1101
# 8               Transporte de pasajeros por carretera        1101
# 9               Transporte de pasajeros por carretera        1101
# 10              Transporte de pasajeros por carretera        1101
# 11              Transporte de pasajeros por carretera        1101
# 12              Transporte de pasajeros por carretera        1101
# 13              Transporte de pasajeros por carretera        1101
# 14                   Transporte de pasajeros por agua        1101
# 15                      Transporte aéreo de pasajeros        1101
# 16                  Alquiler de equipos de transporte        1101
# 17  Actividades de agencias de viajes y de otros s...        1101
# 18                             Actividades culturales        1101
# 19                             Actividades culturales        1101
#
#    ACT Prioritaria  Unnamed: 16
# 0               SI          NaN
# 1               SI          NaN
# 2               NO          NaN
# 3               SI          NaN
# 4               SI          NaN
# 5               SI          NaN
# 6               SI          NaN
# 7               SI          NaN
# 8               NO          NaN
# 9               NO          NaN
# 10              SI          NaN
# 11              SI          NaN
# 12              SI          NaN
# 13              SI          NaN
# 14              SI          NaN
# 15              SI          NaN
# 16              SI          NaN
# 17              SI          NaN
# 18              SI          NaN
# 19              SI          NaN
