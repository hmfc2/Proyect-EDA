# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

import pandas as pd

# %%
# La base de datos del censo, vienen en un excel en diferentes hojas, entonces se guardo la hoja que se va a usar en .csv.
# que quedo y se llamo poblacionporedad.
# link de acceso: https://drive.google.com/file/d/1x1e4z1BEqpub_GKY1AEE1hQYaaBi18Mo/view?usp=sharing

# La base de datos del censo, vienen en un excel en diferentes hojas, entonces se guardo la hoja que se va a usar en .csv.
# que quedo y se llamo poblacionporedad.
# link de acceso: https://drive.google.com/file/d/1x1e4z1BEqpub_GKY1AEE1hQYaaBi18Mo/view?usp=sharing

file_id_encuesta = "1x1e4z1BEqpub_GKY1AEE1hQYaaBi18Mo"

url = f"https://drive.google.com/uc?id={file_id_encuesta}"

poblacion = pd.read_csv(
    url,
    sep=";",
    engine="python"
)

poblacion.head(20)
# Out:
#    Código región              Región  Código provincia Provincia  \
# 0              0                País               0.0      País
# 1              0                País               0.0      País
# 2              0                País               0.0      País
# 3              0                País               0.0      País
# 4              0                País               0.0      País
# 5              0                País               0.0      País
# 6              0                País               0.0      País
# 7              0                País               0.0      País
# 8              0                País               0.0      País
# 9              0                País               0.0      País
# 10             0                País               0.0      País
# 11             0                País               0.0      País
# 12             0                País               0.0      País
# 13             0                País               0.0      País
# 14             0                País               0.0      País
# 15             0                País               0.0      País
# 16             0                País               0.0      País
# 17             0                País               0.0      País
# 18             0                País               0.0      País
# 19            15  Arica y Parinacota             151.0     Arica
#
#     Código comuna Comuna Grupos de edad Población censada    Hombres  \
# 0             0.0   País     Total País        18.480.432  8.967.033
# 1             0.0   País          0 a 4           870.693    443.028
# 2             0.0   País          5 a 9         1.147.515    584.218
# 3             0.0   País        10 a 14         1.256.440    641.284
# 4             0.0   País        15 a 19         1.219.347    625.986
# 5             0.0   País        20 a 24         1.273.193    646.831
# 6             0.0   País        25 a 29         1.383.669    693.829
# 7             0.0   País        30 a 34         1.527.489    758.913
# 8             0.0   País        35 a 39         1.408.198    692.292
# 9             0.0   País        40 a 44         1.270.493    615.866
# 10            0.0   País        45 a 49         1.151.776    549.508
# 11            0.0   País        50 a 54         1.173.352    556.491
# 12            0.0   País        55 a 59         1.133.239    530.699
# 13            0.0   País        60 a 64         1.077.790    501.042
# 14            0.0   País        65 a 69           870.801    403.425
# 15            0.0   País        70 a 74           646.241    292.622
# 16            0.0   País        75 a 79           477.186    208.574
# 17            0.0   País        80 a 84           317.424    129.155
# 18            0.0   País       85 o más           275.586     93.270
# 19        15101.0  Arica   Total Comuna           241.653    118.844
#
#       Mujeres Razón hombre-mujer
# 0   9.513.399               94,3
# 1     427.665              103,6
# 2     563.297              103,7
# 3     615.156              104,2
# 4     593.361              105,5
# 5     626.362              103,3
# 6     689.840              100,6
# 7     768.576               98,7
# 8     715.906               96,7
# 9     654.627               94,1
# 10    602.268               91,2
# 11    616.861               90,2
# 12    602.540               88,1
# 13    576.748               86,9
# 14    467.376               86,3
# 15    353.619               82,8
# 16    268.612               77,6
# 17    188.269               68,6
# 18    182.316               51,2
# 19    122.809               96,8

# %%
poblacion.shape

# %%
print (poblacion.columns.tolist())
poblacion.info()
